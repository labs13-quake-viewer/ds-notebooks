# %%
import pandas as pd

# %%
# Loading the data
# Earthquakes in Japan from 1992 to 2005

df = pd.read_csv('/Users/shilpasingh/Downloads/query (2).csv')

# %%
df.tail()
# Out:
#                          time  latitude  longitude  depth  mag magType  nst  \
# 803  1992-02-01T19:04:04.530Z    35.106    139.644  100.0  5.8      mw  NaN
# 804  1992-01-22T01:06:55.510Z    38.470    140.308  115.7  5.7      mw  NaN
# 805  1992-01-16T18:46:49.730Z    41.514    141.850   72.6  5.4      mw  NaN
# 806  1992-01-06T20:44:12.460Z    33.459    138.643   20.8  5.1      ms  NaN
# 807  1992-01-05T11:38:46.870Z    35.497    140.237   71.9  5.2      mb  NaN
#
#      gap  dmin  rms  ...                   updated  \
# 803  NaN   NaN  0.9  ...  2017-04-13T22:04:13.851Z
# 804  NaN   NaN  0.9  ...  2016-11-09T21:43:42.034Z
# 805  NaN   NaN  1.2  ...  2016-11-09T21:41:06.938Z
# 806  NaN   NaN  1.3  ...  2014-11-07T00:49:53.535Z
# 807  NaN   NaN  0.7  ...  2014-11-07T00:49:53.161Z
#
#                                      place        type horizontalError  \
# 803  near the south coast of Honshu, Japan  earthquake             NaN
# 804                  eastern Honshu, Japan  earthquake             NaN
# 805                 Hokkaido, Japan region  earthquake             NaN
# 806              Izu Islands, Japan region  earthquake             NaN
# 807   near the east coast of Honshu, Japan  earthquake             NaN
#
#     depthError  magError  magNst    status  locationSource magSource
# 803        NaN       NaN     NaN  reviewed              us       hrv
# 804        NaN       NaN     NaN  reviewed              us       hrv
# 805        NaN       NaN     NaN  reviewed              us       hrv
# 806        NaN       NaN     3.0  reviewed              us        us
# 807        6.8       NaN     5.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=807, step=1)

# %%
# Changing the index from 0 to 1

df.index = df.index+1

# %%
df.index
# Out:
# RangeIndex(start=1, stop=808, step=1)

# %%
df.shape
# Out:
# (807, 22)

# %%
# Selecting only the earthquakes that occured in Japan.

df1 = df[df.place.str.contains('Japan')]

# %%
df1.shape
# Out:
# (805, 22)

# %%
df1.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
df1.tail().T
# Out:
#                                                    803  \
# time                          1992-02-01T19:04:04.530Z
# latitude                                        35.106
# longitude                                      139.644
# depth                                              100
# mag                                                5.8
# magType                                             mw
# nst                                                NaN
# gap                                                NaN
# dmin                                               NaN
# rms                                                0.9
# net                                                 us
# id                                          usp00052gf
# updated                       2017-04-13T22:04:13.851Z
# place            near the south coast of Honshu, Japan
# type                                        earthquake
# horizontalError                                    NaN
# depthError                                         NaN
# magError                                           NaN
# magNst                                             NaN
# status                                        reviewed
# locationSource                                      us
# magSource                                          hrv
#
#                                       804                       805  \
# time             1992-01-22T01:06:55.510Z  1992-01-16T18:46:49.730Z
# latitude                            38.47                    41.514
# longitude                         140.308                    141.85
# depth                               115.7                      72.6
# mag                                   5.7                       5.4
# magType                                mw                        mw
# nst                                   NaN                       NaN
# gap                                   NaN                       NaN
# dmin                                  NaN                       NaN
# rms                                   0.9                       1.2
# net                                    us                        us
# id                             usp0005225                usp00051vg
# updated          2016-11-09T21:43:42.034Z  2016-11-09T21:41:06.938Z
# place               eastern Honshu, Japan    Hokkaido, Japan region
# type                           earthquake                earthquake
# horizontalError                       NaN                       NaN
# depthError                            NaN                       NaN
# magError                              NaN                       NaN
# magNst                                NaN                       NaN
# status                           reviewed                  reviewed
# locationSource                         us                        us
# magSource                             hrv                       hrv
#
#                                        806  \
# time              1992-01-06T20:44:12.460Z
# latitude                            33.459
# longitude                          138.643
# depth                                 20.8
# mag                                    5.1
# magType                                 ms
# nst                                    NaN
# gap                                    NaN
# dmin                                   NaN
# rms                                    1.3
# net                                     us
# id                              usp00051fr
# updated           2014-11-07T00:49:53.535Z
# place            Izu Islands, Japan region
# type                            earthquake
# horizontalError                        NaN
# depthError                             NaN
# magError                               NaN
# magNst                                   3
# status                            reviewed
# locationSource                          us
# magSource                               us
#
#                                                   807
# time                         1992-01-05T11:38:46.870Z
# latitude                                       35.497
# longitude                                     140.237
# depth                                            71.9
# mag                                               5.2
# magType                                            mb
# nst                                               NaN
# gap                                               NaN
# dmin                                              NaN
# rms                                               0.7
# net                                                us
# id                                         usp00051du
# updated                      2014-11-07T00:49:53.161Z
# place            near the east coast of Honshu, Japan
# type                                       earthquake
# horizontalError                                   NaN
# depthError                                        6.8
# magError                                          NaN
# magNst                                              5
# status                                       reviewed
# locationSource                                     us
# magSource                                          us

# %%
# Deleting unwanted columns

cols_of_interest = ['time','latitude','longitude','depth','mag','magType','place','id']

df1 = df1[cols_of_interest]
print(df1.shape)
df1.head()
# Out:
# (805, 8)
#                        time  latitude  longitude  depth  mag magType  \
# 1  2005-12-20T22:58:03.740Z    37.920    143.311   28.0  5.0     mwc
# 2  2005-12-20T05:34:41.710Z    34.529    136.629  354.4  5.0     mwr
# 3  2005-12-16T18:32:16.420Z    38.506    141.900   42.9  6.0     mwc
# 4  2005-12-04T22:20:27.460Z    37.884    142.443   35.2  5.2     mwc
# 5  2005-12-04T18:03:17.640Z    40.143    142.639   45.7  5.0     mwc
#
#                                   place          id
# 1   off the east coast of Honshu, Japan  usp000e6hc
# 2                 western Honshu, Japan  usp000e6fv
# 3  near the east coast of Honshu, Japan  usp000e69b
# 4   off the east coast of Honshu, Japan  usp000e5hr
# 5  near the east coast of Honshu, Japan  usp000e5hd

# %%
df1.mag.value_counts()
# Out:
# 5.0    139
# 5.1    119
# 5.2    119
# 5.3     95
# 5.4     71
# 5.5     48
# 5.7     46
# 5.6     35
# 5.8     28
# 5.9     26
# 6.0     17
# 6.1     14
# 6.2      8
# 6.6      7
# 6.3      7
# 6.4      6
# 6.5      5
# 6.7      4
# 6.9      3
# 7.0      3
# 7.2      2
# 7.4      1
# 7.8      1
# 6.8      1
# Name: mag, dtype: int64

# %%
df1.dtypes
# Out:
# time          object
# latitude     float64
# longitude    float64
# depth        float64
# mag          float64
# magType       object
# place         object
# id            object
# dtype: object
